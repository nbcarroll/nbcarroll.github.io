# %%
import pandas as pd
import numpy as np

# read csv
df = pd.read_csv('processed_aircraft_registration_2015.csv')
# Out:
# C:\Users\nickb\AppData\Local\Temp\ipykernel_30508\3225492317.py:5: DtypeWarning: Columns (18,19,24,25,26,27,28,30,34) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('processed_aircraft_registration_2015.csv')

# %%
df.head()
# Out:
#   N-Number                   Serial Number AircraftMFRModelCode  \
# 0    1AJ    156H                                        7220282
# 1    7D     D-1                                         4970150
# 2    1BH                           1951034              13007S6
# 3    721NM  11E-1001                                    7320100
# 4     6334
#
#   Engine MFR Code Year Mfr  Type Registrant  \
# 0           41514     1973              NaN
# 1           41508     1951              NaN
# 2           43101     1972              NaN
# 3           17160     2008              NaN
# 4                                       NaN
#
#                                                 Name  \
# 0  JENKINS ARTHUR J                              ...
# 1  HOLLIDAY MARK E                               ...
# 2  HINSON BOBBY W                                ...
# 3  CINCO FUND III LLC                            ...
# 4  NIEUPORT LLC                                  ...
#
# ...

# %% [markdown]
# Since INT is more efficient for processing than VARCHAR, we'll examine if any columns contain only numeric values to optimize our MySQL database performance.

# %%
# Check if any columns only contain numeric values (int or float)
df.apply(lambda s: pd.to_numeric(s, errors='coerce').notnull().all())
# Out:
# N-Number                   False
# Serial Number              False
# AircraftMFRModelCode       False
# Engine MFR Code            False
# Year Mfr                   False
# Type Registrant            False
# Name                       False
# Street1                    False
# Street2                    False
# City                       False
# State                      False
# ZIP                        False
# Region                     False
# County                     False
# Country                    False
# LastActivity Date          False
# CertIssueDate              False
# Certification Requested    False
# TypeAcft                   False
# Type Engine                False
# StatusCode                 False
# Mode S Code                 True
# Fractional Ownership       False
# Airworthiness Date         False
# Other Name 1               False
# Other Name 2               False
# Other Name 3               False
# Other Name 4               False
# ...

# %% [markdown]
# It loooks like only the 'Mode S Code' column contains only numeric values. When creating this Column in MySQL Workbench, we'll assign the Datatype as INT.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 437916 entries, 0 to 437915
# Data columns (total 35 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   N-Number                 437916 non-null  object
#  1   Serial Number            437916 non-null  object
#  2   AircraftMFRModelCode     437916 non-null  object
#  3   Engine MFR Code          437916 non-null  object
#  4   Year Mfr                 437916 non-null  object
#  5   Type Registrant          0 non-null       float64
#  6   Name                     437916 non-null  object
#  7   Street1                  437916 non-null  object
#  8   Street2                  437916 non-null  object
#  9   City                     437916 non-null  object
#  10  State                    437916 non-null  object
#  11  ZIP                      437916 non-null  object
#  12  Region                   437916 non-null  object
# ...
